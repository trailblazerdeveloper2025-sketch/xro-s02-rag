# %% [markdown]
# # Welcome to XRO Tech Lab
#
# **Program:** AI + Google Cloud Architecture Program — Batch 2
#
# **Student:** s02
#
# Run the cells below to verify your environment.

# %%
import os
print('=' * 50)
print('  XRO Tech - Lab Environment Check')
print('=' * 50)
print('  Student  :', 's02')
print('  Project  :', 'xro-lab')
print('  Workspace:', os.getcwd())
print('=' * 50)
try:
    import google.auth
    creds, proj = google.auth.default()
    print('  GCP Auth : Connected OK')
except Exception as e:
    print('  GCP Auth : FAILED -', e)
print('=' * 50)
# Out:
# ...
#   XRO Tech - Lab Environment Check
# ...
#   Student  : s02
#   Project  : xro-lab
#   Workspace: /home/s02/workspace
# ...
#   GCP Auth : Connected OK
# ...

# %%
# Test Vertex AI (Gemini)
import vertexai
from vertexai.generative_models import GenerativeModel

vertexai.init(project='xro-lab', location='asia-south1')
model = GenerativeModel('gemini-2.5-flash')
response = model.generate_content(
    'Say hello to an AI student in Bodoland, Assam in one sentence.'
)
print('Gemini says:')
print(response.text)
# Out:
# /usr/local/lib/python3.11/dist-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# Gemini says:
# Hello to the AI student in Bodoland, Assam!
